# %% [markdown]
# # 🎓 Lab 01: พื้นฐาน Python สำหรับ RAG System
#
# ---
#
# ## 📋 ข้อมูล Lab
#
# | หัวข้อ | รายละเอียด |
# |--------|------------|
# | **วิชา** | CSI403 - Full Stack RAG with Local LLM |
# | **Lab** | Lab 01 |
# | **หัวข้อ** | Python Basics for RAG |
# | **คะแนน** | 100 คะแนน |
#
# ---
#
# ## 🎯 วัตถุประสงค์
#
# เมื่อทำ Lab นี้เสร็จ นักศึกษาจะ:
#
# 1. ✅ เข้าใจ Data Types พื้นฐาน (string, list, dictionary)
# 2. ✅ เข้าใจ Function และ Class เบื้องต้น
# 3. ✅ สามารถสร้าง Document class สำหรับระบบ RAG
# 4. ✅ สามารถทำ Text Processing พื้นฐาน
#
# ---
#
# ## 📚 RAG System คืออะไร?
#
# **RAG = Retrieval-Augmented Generation**
#
# ```
# ┌─────────────┐    ┌─────────────┐    ┌─────────────┐
# │   📄 เอกสาร   │───▶│  🔍 ค้นหา   │───▶│  🤖 AI ตอบ  │
# │  (Documents) │    │  (Retrieve)  │    │  (Generate) │
# └─────────────┘    └─────────────┘    └─────────────┘
# ```
#
# **ตัวอย่าง:**
# - User ถาม: "อาการของโรคหัดเยอรมันคืออะไร?"
# - ระบบ RAG ค้นหาเอกสารที่เกี่ยวข้อง
# - AI ใช้ข้อมูลจากเอกสารเพื่อตอบคำถาม

# %% [markdown]
# ---
#
# # 📖 Part 1: Python Basics Review (20 คะแนน)
#
# ก่อนสร้างระบบ RAG มาทบทวน Python พื้นฐานกัน

# %% [markdown]
# ## 1.1 String - ข้อความ
#
# String คือข้อมูลประเภทข้อความ ใช้เก็บเนื้อหาเอกสาร

# %%
# ตัวอย่าง: สร้าง String
title = "Introduction to RAG"
content = "RAG is a technique that combines retrieval and generation."

print("Title:", title)
print("Content:", content)

# %%
# String Methods ที่ใช้บ่อย

# 1. len() - นับจำนวนตัวอักษร
print("จำนวนตัวอักษร:", len(content))

# 2. split() - แยกคำ
words = content.split()  # แยกด้วย space
print("คำทั้งหมด:", words)
print("จำนวนคำ:", len(words))

# 3. lower() - แปลงเป็นตัวพิมพ์เล็ก
print("ตัวเล็ก:", title.lower())

# %% [markdown]
# ### ✏️ แบบฝึกหัด 1.1 (5 คะแนน)
#
# จากข้อความด้านล่าง ให้:
# 1. นับจำนวนตัวอักษร
# 2. นับจำนวนคำ

# %%
# แบบฝึกหัด 1.1
text = "OpenSearch is a powerful search engine for RAG systems"

# TODO: นับจำนวนตัวอักษร
char_count = ___  # แก้ตรงนี้

# TODO: นับจำนวนคำ
word_count = ___  # แก้ตรงนี้

print(f"จำนวนตัวอักษร: {char_count}")
print(f"จำนวนคำ: {word_count}")

# %% [markdown]
# ## 1.2 List - รายการ
#
# List ใช้เก็บข้อมูลหลายๆ ชิ้น เช่น รายการเอกสาร, รายการ chunks

# %%
# ตัวอย่าง: สร้าง List
documents = ["doc1.md", "doc2.md", "doc3.md"]

print("เอกสารทั้งหมด:", documents)
print("จำนวนเอกสาร:", len(documents))
print("เอกสารแรก:", documents[0])  # index เริ่มจาก 0

# %%
# List Methods ที่ใช้บ่อย

# 1. append() - เพิ่มข้อมูล
documents.append("doc4.md")
print("หลังเพิ่ม:", documents)

# 2. for loop - วนลูป
print("\nรายการเอกสาร:")
for doc in documents:
    print(f"  - {doc}")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 1.2 (5 คะแนน)
#
# สร้าง list ที่เก็บชื่อโรค 3 โรค และแสดงผลด้วย for loop

# %%
# แบบฝึกหัด 1.2

# TODO: สร้าง list ชื่อโรค 3 โรค
diseases = ___  # แก้ตรงนี้ เช่น ["โรค1", "โรค2", "โรค3"]

# TODO: แสดงผลด้วย for loop
print("รายการโรค:")
for disease in diseases:
    print(f"  - {disease}")

# %% [markdown]
# ## 1.3 Dictionary - พจนานุกรม
#
# Dictionary เก็บข้อมูลแบบ key-value ใช้เก็บข้อมูลเอกสารที่มีหลาย fields

# %%
# ตัวอย่าง: สร้าง Dictionary
document = {
    "title": "หัดเยอรมัน",
    "content": "หัดเยอรมันเป็นโรคติดต่อที่เกิดจากไวรัส",
    "source": "health.md",
    "word_count": 8
}

print("เอกสาร:", document)

# %%
# เข้าถึงข้อมูลใน Dictionary

print("ชื่อเอกสาร:", document["title"])
print("เนื้อหา:", document["content"])
print("จำนวนคำ:", document["word_count"])

# %% [markdown]
# ### ✏️ แบบฝึกหัด 1.3 (10 คะแนน)
#
# สร้าง dictionary เก็บข้อมูลโรค 1 โรค ที่มี:
# - name: ชื่อโรค
# - symptoms: อาการ (เป็น list)
# - treatment: วิธีรักษา

# %%
# แบบฝึกหัด 1.3

# TODO: สร้าง dictionary เก็บข้อมูลโรค
disease_info = {
    "name": ___,        # แก้ตรงนี้ - ชื่อโรค
    "symptoms": ___,    # แก้ตรงนี้ - list อาการ เช่น ["ไข้", "ปวดหัว"]
    "treatment": ___    # แก้ตรงนี้ - วิธีรักษา
}

# แสดงผล
print(f"โรค: {disease_info['name']}")
print(f"อาการ: {disease_info['symptoms']}")
print(f"วิธีรักษา: {disease_info['treatment']}")

# %% [markdown]
# ---
#
# # 📖 Part 2: Function - ฟังก์ชัน (20 คะแนน)
#
# Function ช่วยให้เราเขียนโค้ดที่ใช้ซ้ำได้

# %%
# ตัวอย่าง: Function นับจำนวนคำ

def count_words(text):
    """
    นับจำนวนคำในข้อความ
    
    Args:
        text: ข้อความที่ต้องการนับ
    
    Returns:
        int: จำนวนคำ
    """
    words = text.split()
    return len(words)

# ทดสอบ
sample = "RAG is a powerful technique"
result = count_words(sample)
print(f"'{sample}' มี {result} คำ")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 2.1 (10 คะแนน)
#
# เขียน function `get_summary(text, max_length)` ที่:
# - รับ text และ max_length
# - ถ้า text สั้นกว่า max_length → return text ทั้งหมด
# - ถ้า text ยาวกว่า max_length → return text[:max_length] + "..."

# %%
# แบบฝึกหัด 2.1

def get_summary(text, max_length=50):
    """
    สร้างสรุปข้อความ
    
    Args:
        text: ข้อความต้นฉบับ
        max_length: ความยาวสูงสุด (default: 50)
    
    Returns:
        str: ข้อความที่ถูกตัด + "..." (ถ้าจำเป็น)
    """
    # TODO: เขียนโค้ดที่นี่
    # Hint: ใช้ if-else และ len()
    pass  # ลบบรรทัดนี้แล้วเขียนโค้ด

# ทดสอบ
short_text = "Hello World"
long_text = "RAG (Retrieval-Augmented Generation) is a technique that combines retrieval and generation for better results."

print(f"Short: '{get_summary(short_text, 50)}'")
print(f"Long: '{get_summary(long_text, 50)}'")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 2.2 (10 คะแนน)
#
# เขียน function `chunk_text(text, chunk_size)` ที่:
# - แบ่ง text เป็นชิ้นๆ ตาม chunk_size (จำนวนคำ)
# - return เป็น list ของ chunks

# %%
# แบบฝึกหัด 2.2

def chunk_text(text, chunk_size=5):
    """
    แบ่งข้อความเป็น chunks
    
    Args:
        text: ข้อความต้นฉบับ
        chunk_size: จำนวนคำต่อ chunk
    
    Returns:
        list: รายการ chunks
    
    Example:
        >>> chunk_text("one two three four five six", 3)
        ['one two three', 'four five six']
    """
    # TODO: เขียนโค้ดที่นี่
    # Hint:
    # 1. แยกคำด้วย split()
    # 2. ใช้ for loop กับ range(0, len(words), chunk_size)
    # 3. รวมคำด้วย " ".join()
    pass  # ลบบรรทัดนี้แล้วเขียนโค้ด

# ทดสอบ
sample = "one two three four five six seven eight nine ten"
chunks = chunk_text(sample, 3)
print("Chunks:", chunks)

# %% [markdown]
# ---
#
# # 📖 Part 3: Class - คลาส (30 คะแนน)
#
# Class ช่วยให้เราสร้าง "พิมพ์เขียว" สำหรับ objects ที่คล้ายกัน
#
# ในระบบ RAG เราจะสร้าง `Document` class เพื่อเก็บข้อมูลเอกสาร

# %%
# ตัวอย่าง: Class พื้นฐาน

class SimpleDocument:
    """Class เก็บข้อมูลเอกสารอย่างง่าย"""
    
    def __init__(self, title, content):
        """
        สร้าง Document ใหม่
        
        Args:
            title: ชื่อเอกสาร
            content: เนื้อหา
        """
        self.title = title      # เก็บ title
        self.content = content  # เก็บ content
    
    def show(self):
        """แสดงข้อมูลเอกสาร"""
        print(f"Title: {self.title}")
        print(f"Content: {self.content}")

# สร้าง object
doc = SimpleDocument("Test", "Hello World")
doc.show()

# %% [markdown]
# ### ✏️ แบบฝึกหัด 3.1 (30 คะแนน)
#
# สร้าง `Document` class ที่สมบูรณ์ ประกอบด้วย:
#
# **Attributes:**
# - `title` (str): ชื่อเอกสาร
# - `content` (str): เนื้อหา
# - `source` (str): แหล่งที่มา (optional)
# - `word_count` (int): จำนวนคำ (คำนวณอัตโนมัติ)
#
# **Methods:**
# - `get_summary(max_length)`: return สรุปเนื้อหา
# - `get_word_count()`: return จำนวนคำ
# - `to_dict()`: return dictionary ของข้อมูล

# %%
# แบบฝึกหัด 3.1 - Document Class

class Document:
    """
    Class เก็บข้อมูลเอกสารสำหรับระบบ RAG
    
    Attributes:
        title (str): ชื่อเอกสาร
        content (str): เนื้อหา
        source (str): แหล่งที่มา
        word_count (int): จำนวนคำ
    """
    
    def __init__(self, title, content, source=None):
        """
        สร้าง Document ใหม่
        
        Args:
            title: ชื่อเอกสาร
            content: เนื้อหา
            source: แหล่งที่มา (optional)
        """
        self.title = title
        self.content = content
        self.source = source
        
        # TODO: คำนวณ word_count จาก content
        # Hint: ใช้ len(content.split())
        self.word_count = ___  # แก้ตรงนี้
    
    def get_summary(self, max_length=100):
        """
        สร้างสรุปเนื้อหา
        
        Args:
            max_length: ความยาวสูงสุด
        
        Returns:
            str: เนื้อหาที่ถูกตัด + "..." (ถ้าจำเป็น)
        """
        # TODO: implement method นี้
        # - ถ้า content สั้นกว่า max_length → return content
        # - ถ้า content ยาวกว่า max_length → return content[:max_length] + "..."
        pass  # ลบบรรทัดนี้แล้วเขียนโค้ด
    
    def get_word_count(self):
        """
        คืนค่าจำนวนคำ
        
        Returns:
            int: จำนวนคำ
        """
        # TODO: return word_count
        pass  # ลบบรรทัดนี้แล้วเขียนโค้ด
    
    def to_dict(self):
        """
        แปลงเป็น Dictionary
        
        Returns:
            dict: ข้อมูลเอกสาร
        """
        # TODO: return dictionary ที่มี keys: title, content, source, word_count
        pass  # ลบบรรทัดนี้แล้วเขียนโค้ด
    
    def __repr__(self):
        """แสดงข้อมูล object"""
        return f"Document(title='{self.title}', words={self.word_count})"

# %%
# ทดสอบ Document class

# สร้าง Document
doc = Document(
    title="หัดเยอรมัน",
    content="หัดเยอรมันเป็นโรคติดต่อที่เกิดจากไวรัส มีอาการไข้ ผื่น และต่อมน้ำเหลืองโต",
    source="health.md"
)

# ทดสอบ
print("1. Document:", doc)
print("2. Word count:", doc.get_word_count())
print("3. Summary:", doc.get_summary(30))
print("4. To dict:", doc.to_dict())

# %% [markdown]
# ---
#
# # 📖 Part 4: Document Processing (30 คะแนน)
#
# มาประยุกต์ใช้ความรู้ทั้งหมดเพื่อประมวลผลเอกสารหลายๆ ไฟล์

# %% [markdown]
# ## 4.1 อ่านไฟล์ Markdown
#
# ระบบ RAG มักใช้ไฟล์ .md (Markdown) เป็นแหล่งข้อมูล

# %%
# ตัวอย่าง: อ่านไฟล์ Markdown

def read_markdown(filepath):
    """
    อ่านไฟล์ Markdown และสร้าง Document
    
    Args:
        filepath: path ของไฟล์
    
    Returns:
        Document: object ของเอกสาร
    """
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()
    
    # ดึง title จากบรรทัดแรก (# Title)
    lines = content.split('\n')
    title = lines[0].replace('#', '').strip() if lines else 'Untitled'
    
    return Document(title=title, content=content, source=filepath)

# สมมติว่ามีไฟล์ (จะทำงานจริงต้องมีไฟล์)
# doc = read_markdown('health.md')
print("Function read_markdown พร้อมใช้งาน")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 4.1 (15 คะแนน)
#
# สร้าง function `process_documents(documents)` ที่:
# - รับ list ของ Document objects
# - return dictionary ที่มี:
#   - `total_documents`: จำนวนเอกสารทั้งหมด
#   - `total_words`: จำนวนคำทั้งหมด
#   - `average_words`: จำนวนคำเฉลี่ยต่อเอกสาร
#   - `titles`: list ของชื่อเอกสาร

# %%
# แบบฝึกหัด 4.1

def process_documents(documents):
    """
    ประมวลผลรายการเอกสาร
    
    Args:
        documents: list ของ Document objects
    
    Returns:
        dict: สรุปข้อมูลเอกสาร
    """
    # TODO: เขียนโค้ดที่นี่
    # Hint:
    # 1. วนลูป documents เพื่อรวม word_count และเก็บ title
    # 2. คำนวณ average
    # 3. return dictionary
    pass  # ลบบรรทัดนี้แล้วเขียนโค้ด

# ทดสอบ
docs = [
    Document("Doc 1", "Hello World"),
    Document("Doc 2", "This is a longer document with more words"),
    Document("Doc 3", "Short text")
]

stats = process_documents(docs)
print("Statistics:", stats)

# %% [markdown]
# ### ✏️ แบบฝึกหัด 4.2 (15 คะแนน)
#
# สร้าง function `search_documents(documents, query)` ที่:
# - ค้นหาเอกสารที่มี query อยู่ใน content
# - return list ของ Document ที่ตรงกัน

# %%
# แบบฝึกหัด 4.2

def search_documents(documents, query):
    """
    ค้นหาเอกสารที่มี query
    
    Args:
        documents: list ของ Document objects
        query: คำค้นหา
    
    Returns:
        list: เอกสารที่ตรงกัน
    """
    # TODO: เขียนโค้ดที่นี่
    # Hint:
    # 1. แปลง query และ content เป็นตัวเล็กด้วย .lower()
    # 2. ใช้ 'in' เพื่อตรวจสอบ
    # 3. เก็บเอกสารที่ตรงลงใน list
    pass  # ลบบรรทัดนี้แล้วเขียนโค้ด

# ทดสอบ
docs = [
    Document("หัดเยอรมัน", "หัดเยอรมันเป็นโรคติดต่อ มีอาการไข้"),
    Document("ไข้หวัด", "ไข้หวัดเป็นโรคทางเดินหายใจ มีอาการไข้ ไอ"),
    Document("ต้อกระจก", "ต้อกระจกเป็นโรคตา พบในผู้สูงอายุ")
]

results = search_documents(docs, "ไข้")
print(f"พบ {len(results)} เอกสารที่มีคำว่า 'ไข้':")
for doc in results:
    print(f"  - {doc.title}")

# %% [markdown]
# ---
#
# # ✅ สรุป Lab 01
#
# ในLab นี้ นักศึกษาได้เรียนรู้:
#
# 1. **Python Basics**: String, List, Dictionary
# 2. **Function**: การสร้างและใช้งาน function
# 3. **Class**: การสร้าง Document class สำหรับ RAG
# 4. **Document Processing**: การประมวลผลเอกสาร
#
# ---
#
# ## 📊 คะแนน
#
# | Part | คะแนน |
# |------|-------|
# | Part 1: Python Basics | 20 |
# | Part 2: Function | 20 |
# | Part 3: Class | 30 |
# | Part 4: Document Processing | 30 |
# | **รวม** | **100** |
#
# ---
#
# ## 📤 วิธี Submit
#
# 1. บันทึกไฟล์ notebook นี้
# 2. รัน cells ทั้งหมดให้แสดงผล
# 3. Commit และ Push ขึ้น GitHub
#
# ```bash
# git add .
# git commit -m "Complete Lab 01"
# git push
# ```
#
# ---
#
# ## 🎯 Lab ถัดไป
#
# **Lab 02**: Docker & OpenSearch - เรียนรู้การตั้งค่า Vector Database
